# %%
import os
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI

load_dotenv()
# Out:
# True

# %%
model = os.getenv('OPENAI_MODEL_NAME')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_API_URL = os.getenv('OPENAI_BASE_URL')

# %%
llm = ChatOpenAI(
    model=model,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_API_URL,
    temperature=0.5,
)

propmt = '你好'

print(llm.invoke(prot))
# Out:
# content='你好！很高兴见到你。有需要的话可以告诉我你想聊的话题，或者直接说出你遇到的问题。我可以用中文或英文交流，也能帮你解答问题、翻译、写作、学习、编程等。你现在想聊点什么？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 264, 'prompt_tokens': 7, 'total_tokens': 271, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtPEXOzlen3l1nRVmSTkoN4uNZJBz', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b7c8b-71ff-7be1-8df6-c7e6f72d5c29-0' usage_metadata={'input_tokens': 7, 'output_tokens': 264, 'total_tokens': 271, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}
